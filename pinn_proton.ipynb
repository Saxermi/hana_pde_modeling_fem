# %% [markdown]
# Pinn to solve lorentz equation

# %% [markdown]
# first we import the data set and implement a way to sample the magnetic field

# %%
import pandas as pd
import numpy as np
from scipy.spatial import cKDTree

# Load the magnetic field data from a CSV file
data = pd.read_csv(
    "results.csv"
)  # Ensure the file has columns: x, y, z, Bx, By, Bz
positions = data[["x", "y", "z"]].values  # Position data
fields = data[["Bx", "By", "Bz"]].values  # Magnetic field components

# Create a k-d tree for efficient nearest-neighbor queries
tree = cKDTree(positions)


def magnetic_field(position):
    """
    Query the magnetic field for a given position.
    Args:
        position (list or np.array): [x, y, z] position in space.
    Returns:
        np.array: [Bx, By, Bz] magnetic field vector at the queried position.
    """
    _, idx = tree.query(position)  # Find nearest neighbor
    return fields[idx]

# %%
data.head(10)
# Out:
#          x        y        z        Bx            By        Bz
# 0  0.03139  0.02795 -0.03004  0.002615  3.259720e-03  0.003193
# 1 -0.04792 -0.01556  0.04822  0.002225  1.149863e-03  0.000000
# 2 -0.00440 -0.01597  0.02577  0.006843  2.228426e-02 -0.008239
# 3  0.04945 -0.03221 -0.01103  0.000000 -1.110008e-03  0.007755
# 4 -0.00804 -0.01265 -0.03829 -0.001783 -3.266066e-03 -0.007275
# 5 -0.02229 -0.02712  0.00005 -0.002743 -4.353262e-03  0.016515
# 6  0.01144  0.04998 -0.00289 -0.000730 -3.433735e-19  0.011642
# 7 -0.00584 -0.01543 -0.00063 -0.010433 -1.899825e-02  0.137786
# 8 -0.03476 -0.04805  0.04129  0.002248  0.000000e+00  0.002022
# 9 -0.01297 -0.04224  0.00540  0.000193  5.680308e-04  0.010637

# %%
import torch
import torch.nn as nn
m = 1.67262192369e-27  # proton mass in kg
q = 1.602176634e-19  # proton charge in Coulombs (or +ve if you want a proton)


class TrajectoryPINN(nn.Module):
    """
    Physics-Informed Neural Network (PINN) for predicting the trajectory of a charged particle.
    This network is designed to take a single time input and predict the spatial coordinates
    (x, y, z) of the particle at that time.
    """

    def __init__(self):
        """
        Initialize the neural network structure.
        The network consists of a series of fully connected (linear) layers with Tanh activation functions.
        """
        super().__init__()  # Call the parent class (nn.Module) constructor

        # Define the network architecture using nn.Sequential.
        # The architecture includes:
        # - An input layer that takes a single value (time t)
        # - Three hidden layers with 128 neurons each and Tanh activation functions
        # - An output layer with 3 neurons, representing the x(t), y(t), and z(t) coordinates
        self.net = nn.Sequential(
            nn.Linear(
                1, 128
            ),  # Input layer: maps 1 input (time t) to 128 hidden neurons
            nn.Tanh(),  # Activation function: Tanh introduces non-linearity
            nn.Linear(
                128, 128
            ),  # Hidden layer: maps 128 neurons to another 128 neurons
            nn.Tanh(),  # Activation function: Tanh
            nn.Linear(128, 128),  # Another hidden layer with 128 neurons
            nn.Tanh(),  # Activation function: Tanh
            nn.Linear(128, 3),  # Output layer: maps 128 neurons to 3 outputs (x, y, z)
        )

    def forward(self, t):
        """
        Perform the forward pass of the network.

        Args:
            t (Tensor): A tensor containing the time input(s) for which to predict the trajectory.
                        Shape: (batch_size, 1), where each row is a single time value.

        Returns:
            Tensor: A tensor containing the predicted (x, y, z) coordinates for the input times.
                    Shape: (batch_size, 3), where each row represents [x(t), y(t), z(t)].
        """
        return self.net(t)  # Pass the input t through the network and return the output

# %%
def physics_loss(model, t, s0, v0, device):
    """
    Compute the loss function for the PINN using the Lorentz force equation.
    Args:
        model (nn.Module): The PINN model.
        t (torch.Tensor): Time values, shape: (N, 1).
        s0 (torch.Tensor): Initial position [x0, y0, z0].
        v0 (torch.Tensor): Initial velocity [vx0, vy0, vz0].
        device (torch.device): Device (CPU or GPU).
    Returns:
        torch.Tensor: The total loss value.
    """
    # Enable autograd for time
    t.requires_grad = True

    # Predicted positions, shape: (N, 3)
    s = model(t)

    # Check shape of s
    if s.shape[1] != 3:
        raise ValueError(f"Expected model output to have shape (N, 3), got {s.shape}")

    # ------------------------------------------------------------------
    # Compute velocity v = ds/dt by taking partial derivatives of each
    # dimension of s w.r.t. t individually, then stacking them.
    # ------------------------------------------------------------------
    v_components = []
    for i in range(3):
        # s[:, i] has shape (N,)
        # We'll compute d(s[:, i]) / dt => shape (N,)
        grad_i = torch.autograd.grad(
            s[:, i],  # outputs
            t,  # inputs
            grad_outputs=torch.ones_like(s[:, i]),
            create_graph=True,
        )[
            0
        ]  # shape: (N, 1)

        v_components.append(grad_i.reshape(-1))  # make it (N,)

    # Stack into (N, 3)
    v = torch.stack(v_components, dim=1)
    # Debugging: Check velocity shape
    if v.shape[1] != 3:
        raise ValueError(f"Expected velocity to have shape (N, 3), got {v.shape}")

    # ------------------------------------------------------------------
    # Compute acceleration a = dv/dt similarly.
    # ------------------------------------------------------------------
    a_components = []
    for i in range(3):
        grad_i = torch.autograd.grad(
            v[:, i], t, grad_outputs=torch.ones_like(v[:, i]), create_graph=True
        )[0]

        a_components.append(grad_i.reshape(-1))

    a = torch.stack(a_components, dim=1)
    # Debugging: Check acceleration shape
    if a.shape[1] != 3:
        raise ValueError(f"Expected acceleration to have shape (N, 3), got {a.shape}")

    # Query magnetic field at predicted positions
    B_values = torch.stack(
        [
            torch.tensor(
                magnetic_field(pos.cpu().detach().numpy()), dtype=torch.float32
            )
            for pos in s
        ]
    ).to(
        device
    )  # Shape: (N, 3)
    #print(B_values)
    # Debugging: Check B_values shape
    if B_values.shape[1] != 3:
        raise ValueError(
            f"Expected B_values to have shape (N, 3), got {B_values.shape}"
        )

    # Lorentz force residual
    lorentz_residual = m * a - q * torch.cross(v, B_values, dim=1)
    physics_loss_val = torch.mean(lorentz_residual**2)

    # Initial conditions loss
    ic_loss = torch.mean((s[0] - s0) ** 2) + torch.mean((v[0] - v0) ** 2)
   # print("current physics loss")
    #print(physics_loss_val)
    #print("current ic loss")
    #print(ic_loss)
    return physics_loss_val + 1.2* ic_loss

# %%
# Training setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = TrajectoryPINN().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=12e-4)

# Initial conditions
s0 = torch.tensor([[0.0, 0.007, -0.05]], device=device)  # Initial position
v0 = torch.tensor([[0.0, 0.0, 1e6]], device=device)  # Initial velocity (z-direction)
t_train = torch.linspace(0, 1e-5, 1000, device=device).unsqueeze(1)  # Time values

# Training loop
for epoch in range(50000):
    optimizer.zero_grad()
    loss = physics_loss(model, t_train, s0, v0, device)
    loss.backward()
    optimizer.step()

    if epoch % 500 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

# Save the trained model
torch.save(model.state_dict(), "trajectory_pinn_3d.pth")
print("Training complete and model saved.")
# Out:
# current physics loss
# tensor(6.1657e-44, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3333e+11, grad_fn=<AddBackward0>)
# Epoch 0, Loss: 333333331968.0
# current physics loss
# tensor(1.4013e-44, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3333e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.5134e-43, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3333e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.4052e-43, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3333e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.9785e-43, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3333e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.2892e-42, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3333e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.2107e-42, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3333e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.0067e-42, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3333e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.2076e-42, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3333e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.9774e-42, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3333e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.5250e-42, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3333e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.4817e-42, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3333e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.9797e-43, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3333e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.7500e-41, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3333e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.2106e-42, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3332e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.5802e-42, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3332e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.1938e-41, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3332e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.1048e-40, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3332e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.3202e-41, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3332e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.4218e-40, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3331e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.1457e-40, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3331e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.8366e-41, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3331e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.4906e-40, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3330e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.5461e-41, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3330e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.6174e-40, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3330e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.2284e-40, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3329e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.0355e-40, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3329e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.6999e-40, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3328e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.6779e-41, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3328e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.4400e-39, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3327e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.5355e-40, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3326e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.6671e-39, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3326e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.4033e-39, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3325e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.6328e-39, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3324e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.1269e-39, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3323e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.2184e-39, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3322e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.0431e-38, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3321e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.1987e-38, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3320e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.5792e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3318e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.6538e-38, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3317e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.3650e-38, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3316e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.9545e-38, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3314e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.4326e-38, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3312e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.4971e-38, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3311e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.2463e-38, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3309e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.7059e-38, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3308e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.2582e-38, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3306e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.8393e-38, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3304e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.4386e-38, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3302e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.6511e-38, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3300e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.0217e-38, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3298e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.8514e-38, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3296e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.0715e-38, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3294e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.9611e-38, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3291e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.1181e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3289e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.1375e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3286e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.3713e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3284e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.4153e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3281e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.7280e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3278e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.9062e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3275e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.8592e-38, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3272e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.2825e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3270e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.2169e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3266e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.3497e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3262e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.0218e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3259e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.5780e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3256e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.2708e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3252e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.9545e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3248e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.1095e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3244e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.9078e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3241e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.4672e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3237e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.5616e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3232e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.8658e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3227e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.1671e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3224e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.3754e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3221e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.7678e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3214e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.1513e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3208e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.6956e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3205e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.6183e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3202e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.4737e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3196e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.5962e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3188e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.0402e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3183e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.1348e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3180e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.6001e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3176e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.4188e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3168e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.0716e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3159e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.5341e-37, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3154e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.1340e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3152e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.7556e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3147e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.3419e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3136e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.4650e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3127e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.1776e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3123e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.5517e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3121e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.2899e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3113e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.8698e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3100e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.0122e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3092e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.5944e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3089e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.0906e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3087e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.7607e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3076e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.5524e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3061e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.7148e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3053e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.1260e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3051e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.7763e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3050e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.3612e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3036e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.4216e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3018e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.6107e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3010e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.8007e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3010e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.9318e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.3009e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.1086e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2992e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.5131e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2972e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.7467e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2963e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.6553e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2964e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.6965e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2964e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.0168e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2946e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.8632e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2921e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.1785e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2910e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.7388e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2912e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.9999e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2916e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.0921e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2897e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.5004e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2868e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.9680e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2853e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.1162e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2855e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.5568e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2864e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.3323e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2847e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.4310e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2811e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.0172e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2791e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.8646e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2792e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.6569e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2805e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.7427e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2796e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.1622e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2754e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.9221e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2725e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.0058e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2721e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.2307e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2737e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.3889e-36, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2742e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.3999e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2698e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.2311e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2656e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.2751e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2644e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.5771e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2659e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.1471e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2680e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.6431e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2645e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.4938e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2588e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.5961e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2563e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.0247e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2569e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.2716e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2602e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.8851e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2596e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.7545e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2526e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.5315e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2480e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.5701e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2474e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.5872e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2503e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.2040e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2536e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.9879e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2475e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.0200e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2402e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.1988e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2375e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.4042e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2389e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.7541e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2443e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.1678e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2437e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.4429e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2339e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.9975e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2280e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.0459e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2272e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.9026e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2314e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.4767e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2376e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.7275e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2298e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.4935e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2197e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.7395e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2158e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.7367e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2168e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.5683e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2242e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.2620e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2283e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.7988e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2149e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.7035e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2057e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.9128e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2034e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.3152e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2072e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.6180e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2182e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.1350e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2146e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.3367e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1988e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.4740e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1913e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.5376e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1906e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.4586e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1974e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.0920e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2106e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.3511e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1985e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.1699e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1828e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.6357e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1766e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.6711e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1762e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.0630e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1842e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.1072e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.2010e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.3652e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1865e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.5739e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1683e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.0830e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1612e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.2451e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1596e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.9741e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1649e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.9623e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1855e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.6632e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1849e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.5457e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1566e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.2519e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1451e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.2814e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1429e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.7240e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1502e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.5957e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1766e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.3863e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1691e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.1703e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1392e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.1585e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1278e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.1938e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1248e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.4788e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1288e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.2349e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1536e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.2463e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1708e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.2056e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1240e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.7898e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1089e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.7482e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1113e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.0335e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1395e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.1262e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1642e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.4181e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1066e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.5884e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0934e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.7516e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1109e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.9908e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1595e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.0626e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1032e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.7643e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0807e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.7718e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0803e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.0713e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1052e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.4543e-35, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1480e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.2368e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0826e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.0247e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0630e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.9317e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0695e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.6774e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1153e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.5987e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1237e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.6537e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0608e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.9760e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0454e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.1535e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0551e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.7963e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1078e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.4784e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1024e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.9703e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0453e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.5974e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0281e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.6645e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0243e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.3265e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0317e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.4972e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0795e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.0618e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1087e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.7248e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0212e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.0255e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0045e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.3585e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0273e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.9962e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1115e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.2189e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0220e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.2818e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9914e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.2328e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9842e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.4196e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9839e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.1220e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0088e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.0741e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1021e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.1607e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0018e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.7649e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9708e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.8101e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9658e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.4285e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9831e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.9255e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0708e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.7977e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0250e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.6487e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9739e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.7511e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9708e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.8946e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0126e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.5002e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0377e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.1900e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9636e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.6359e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9398e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.8217e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9495e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.3144e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0060e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.1856e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.0103e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.6287e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9397e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.8439e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9180e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.9592e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9287e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.7007e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9858e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.6965e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9921e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.8743e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9199e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.9772e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8969e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.1737e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9078e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.8688e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9658e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.6542e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9744e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.8714e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8998e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.0075e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8757e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.2621e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8881e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.2007e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9493e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.2311e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9526e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.9251e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8792e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.3804e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8565e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.0619e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8742e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.1900e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9387e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.9538e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9174e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.3105e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8580e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.0430e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8449e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.6707e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8756e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.2061e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9237e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.3041e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8665e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.3366e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8301e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.4775e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8379e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.8008e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8846e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.3898e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8834e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.1957e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8281e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.0129e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8106e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.1850e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8356e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.2525e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8749e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.2439e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8338e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.0659e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7975e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.2281e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8021e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.9737e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8393e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.1051e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8387e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.7695e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7928e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.0628e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7769e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.7234e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7994e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.4780e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.8265e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.0857e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7922e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.8452e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7617e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.1922e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7677e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.3913e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7977e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.0946e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7899e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.9181e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7529e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.1294e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7428e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.5189e-34, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7644e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.1452e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7779e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.0164e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7463e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.3922e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7243e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.0599e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7345e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.2427e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7558e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.0449e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7388e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.3801e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7105e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.1569e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7091e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.3683e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7287e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.0902e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7268e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.5167e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6987e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.2429e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6876e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.5014e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7015e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.1572e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7095e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.5767e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6867e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.3195e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6692e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.6621e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6762e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.2424e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6882e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.6464e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6732e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.3911e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6525e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.7555e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6530e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.9695e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6651e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.7304e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6573e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.4623e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6365e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.0589e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6315e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.4409e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6416e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.9848e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6393e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.5369e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6202e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.9905e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6113e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.5450e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6186e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.9408e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6196e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.6172e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.6031e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.1059e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5919e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.6501e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5962e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.3654e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5988e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.7044e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5850e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.2232e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5727e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.7910e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5745e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.1917e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5775e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.3325e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5661e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.3444e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5534e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.8639e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5532e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.7969e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5559e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.9000e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5463e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.4709e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5339e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.1381e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5322e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.4671e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5343e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.1747e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5260e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.6035e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5141e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.9080e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5114e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.9359e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5126e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.9566e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5051e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.7426e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.4939e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.2034e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.4905e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.7620e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.4910e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.2414e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.4839e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.2463e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.4733e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.2386e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.4696e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.9169e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.4692e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.3667e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.4624e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.0409e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.4525e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.4493e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.4485e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.0772e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.4475e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.4802e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.4407e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.2217e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.4313e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.5794e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.4273e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.2433e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.4256e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.6338e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.4187e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.3658e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.4100e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.0477e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.4060e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.4156e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.4036e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.5372e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.3966e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.5382e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.3884e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.8551e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.3844e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.8651e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.3814e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.9228e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.3743e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.0658e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.3666e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.0012e-33, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.3627e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.7799e-33, grad_fn=<MeanBackward0>)
# current ic loss
# ...
# current ic loss
# tensor(1.3352e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.2701e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.3285e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.6748e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.3218e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.3262e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.3151e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.0883e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.3084e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.3094e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.3017e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.4165e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.2950e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.1088e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.2883e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.2311e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.2815e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.1450e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.2748e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.7953e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.2680e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.1815e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.2613e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.8266e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.2545e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.6205e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.2478e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.8585e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.2410e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.2566e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.2342e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.8909e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.2274e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.2950e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.2206e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.9238e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.2139e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.3340e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.2070e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.8024e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.2002e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.3737e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.1934e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.9912e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.1866e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.4140e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.1797e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.0258e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.1729e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.0061e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.1660e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.0610e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.1592e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.0741e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.1523e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.0968e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.1454e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.5392e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.1385e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.1331e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.1316e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.5823e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.1247e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.3507e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.1178e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.6263e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.1108e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.3915e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.1039e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.6710e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.0969e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.4331e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.0900e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.4328e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.0830e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.1847e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.0760e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.1054e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.0690e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.2403e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.0620e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.1585e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.0549e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.3659e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.0479e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.8585e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.0408e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.4353e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.0338e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.9077e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.0267e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.4135e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.0196e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.3243e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.0125e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.4736e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(1.0053e+11, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.9103e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(9.9811e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.5369e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(9.9093e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.9956e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(9.8374e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.5817e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(9.7656e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.1149e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(9.6930e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.4076e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(9.6201e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.5627e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(9.5469e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.9302e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(9.4739e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.2257e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(9.4007e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.7229e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(9.3274e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.2831e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(9.2532e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.7724e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(9.1787e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.4538e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(9.1036e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.8231e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(9.0289e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.5521e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(8.9540e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.8748e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(8.8787e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.6535e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(8.8023e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.9285e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(8.7255e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.5290e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(8.6481e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(2.9836e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(8.5708e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.5949e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(8.4931e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.0401e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(8.4151e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.6631e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(8.3359e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.0990e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(8.2558e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.7343e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(8.1747e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.1602e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(8.0932e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.2141e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(8.0111e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.2234e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(7.9286e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.3390e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(7.8449e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.2893e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(7.7603e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.9653e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(7.6740e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.3589e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(7.5861e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.0509e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(7.4964e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.0177e-31, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(7.4052e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.1418e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(7.3122e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.8029e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(7.2173e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(4.2394e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(7.1197e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.8944e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(7.0192e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.0922e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(6.9147e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.6888e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(6.8056e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(7.2887e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(6.6907e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(3.7951e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(6.5690e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.1787e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(6.4381e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.4649e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(6.2952e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.3766e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(6.1358e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.3331e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(5.9531e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.3448e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(5.7362e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.2843e-31, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(5.4676e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.3780e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(5.1181e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.4199e-31, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(4.6416e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.3488e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.9769e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(5.8101e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(3.1114e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.3347e-31, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.3323e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(9.2512e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.2901e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(8.9118e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.7472e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(1.2745e-31, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.9148e+10, grad_fn=<AddBackward0>)
# current physics loss
# tensor(6.2400e-32, grad_fn=<MeanBackward0>)
# current ic loss
# tensor(2.5968e+10, grad_fn=<AddBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 14
#      12 for epoch in range(50000):
#      13     optimizer.zero_grad()
# ---> 14     loss = physics_loss(model, t_train, s0, v0, device)
#      15     loss.backward()
#      16     optimizer.step()
#
# Cell In[12], line 66, in physics_loss(model, t, s0, v0, device)
#      62     raise ValueError(f"Expected acceleration to have shape (N, 3), got {a.shape}")
#      64 # Query magnetic field at predicted positions
#      65 B_values = torch.stack(
# ---> 66     [
#      67         torch.tensor(
#      68             magnetic_field(pos.cpu().detach().numpy()), dtype=torch.float32
#      69         )
#      70         for pos in s
#      71     ]
#      72 ).to(
#      73     device
#      74 )  # Shape: (N, 3)
#      75 #print(B_values)
#      76 # Debugging: Check B_values shape
#      77 if B_values.shape[1] != 3:
#
# Cell In[12], line 68, in <listcomp>(.0)
#      62     raise ValueError(f"Expected acceleration to have shape (N, 3), got {a.shape}")
#      64 # Query magnetic field at predicted positions
#      65 B_values = torch.stack(
#      66     [
#      67         torch.tensor(
# ---> 68             magnetic_field(pos.cpu().detach().numpy()), dtype=torch.float32
#      69         )
#      70         for pos in s
#      71     ]
#      72 ).to(
#      73     device
#      74 )  # Shape: (N, 3)
#      75 #print(B_values)
#      76 # Debugging: Check B_values shape
#      77 if B_values.shape[1] != 3:
#
# Cell In[1], line 24, in magnetic_field(position)
#      16 def magnetic_field(position):
#      17     """
#      18     Query the magnetic field for a given position.
#      19     Args:
#    (...)
#      22         np.array: [Bx, By, Bz] magnetic field vector at the queried position.
#      23     """
# ---> 24     _, idx = tree.query(position)  # Find nearest neighbor
#      25     return fields[idx]
#
# File _ckdtree.pyx:809, in scipy.spatial._ckdtree.cKDTree.query()
#
# File ~/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:2810, in max(a, axis, out, keepdims, initial, where)
#    2692 @array_function_dispatch(_max_dispatcher)
#    2693 @set_module('numpy')
#    2694 def max(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2695          where=np._NoValue):
#    2696     """
#    2697     Return the maximum of an array or maximum along an axis.
#    2698
#    (...)
#    2808     5
#    2809     """
# -> 2810     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2811                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:
